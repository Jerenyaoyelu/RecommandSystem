# %%
from spotlight.cross_validation import random_train_test_split
from spotlight.datasets.movielens import get_movielens_dataset
from spotlight.evaluation import mrr_score
from spotlight.factorization.implicit import ImplicitFactorizationModel
# %run  movielens_sequence.py
# Out:
# Evaluating {'residual': False, 'num_layers': 5, 'nonlinearity': 'relu', 'n_iter': 12, 'loss': 'hinge', 'learning_rate': 0.1, 'l2': 0.0, 'kernel_width': 3, 'embedding_dim': 128, 'dilation_multiplier': 1, 'batch_size': 32, 'dilation': [1, 1, 1, 1, 1]}
# Epoch 0: loss 4.7413808653987415
# Epoch 1: loss 0.45129860605673766
# Epoch 2: loss 0.451500599276963
# Epoch 3: loss 0.45244657880322064
# Epoch 4: loss 0.4535934913779887
# Epoch 5: loss 0.4508018108058315
# Epoch 6: loss 0.4521230861756474
# Epoch 7: loss 0.45142079275366254
# Epoch 8: loss 0.4515406760559263
# Epoch 9: loss 0.4521504086905746
# Epoch 10: loss 0.4523268829307285
# Epoch 11: loss 0.45195565093750073
# Test MRR 0.01180983075348538 val MRR 0.011869956393311364
# Evaluating {'residual': False, 'num_layers': 3, 'nonlinearity': 'relu', 'n_iter': 16, 'loss': 'pointwise', 'learning_rate': 0.05, 'l2': 1e-06, 'kernel_width': 3, 'embedding_dim': 16, 'dilation_multiplier': 2, 'batch_size': 16, 'dilation': [1, 2, 4]}
# Epoch 0: loss 0.5958480237498702
# Epoch 1: loss 0.6697788224367518
# Epoch 2: loss 0.7040991872336689
# Epoch 3: loss 0.7143636862625702
# Epoch 4: loss 0.7049565659282893
# Epoch 5: loss 0.693372148091323
# Epoch 6: loss 0.694025775174347
# Epoch 7: loss 0.6882083114422415
# Epoch 8: loss 0.6786134972141927
# Epoch 9: loss 0.6710353840558376
# Epoch 10: loss 0.6746053157679542
# Epoch 11: loss 0.6681038384766024
# Epoch 12: loss 0.6639420550113053
# Epoch 13: loss 0.6567696130473937
# Epoch 14: loss 0.6423349598524406
# Epoch 15: loss 0.6303550113974727
# Test MRR 0.0022341077791100472 val MRR 0.0026047763474194257
# Evaluating {'residual': False, 'num_layers': 2, 'nonlinearity': 'tanh', 'n_iter': 16, 'loss': 'bpr', 'learning_rate': 0.001, 'l2': 1e-05, 'kernel_width': 5, 'embedding_dim': 64, 'dilation_multiplier': 1, 'batch_size': 32, 'dilation': [1, 1]}
# Epoch 0: loss 0.25021884728099497
# Epoch 1: loss 0.20096410881569035
# Epoch 2: loss 0.19635473212924615
# Epoch 3: loss 0.19413814096936682
# Epoch 4: loss 0.1920499796692229
# Epoch 5: loss 0.19142120130254195
# Epoch 6: loss 0.19149204121099264
# Epoch 7: loss 0.19113183501772407
# Epoch 8: loss 0.18995928736094614
# Epoch 9: loss 0.18763575247396225
# Epoch 10: loss 0.17584518968211532
# Epoch 11: loss 0.1566539493641017
# Epoch 12: loss 0.14394466476559073
# Epoch 13: loss 0.13862599524276517
# Epoch 14: loss 0.13545166026641972
# Epoch 15: loss 0.13256221183385894
# Test MRR 0.02133669587055867 val MRR 0.019321430384951245
# Evaluating {'residual': True, 'num_layers': 4, 'nonlinearity': 'relu', 'n_iter': 12, 'loss': 'hinge', 'learning_rate': 0.001, 'l2': 1e-06, 'kernel_width': 5, 'embedding_dim': 128, 'dilation_multiplier': 1, 'batch_size': 32, 'dilation': [1, 1, 1, 1]}
# Epoch 0: loss 0.4533377125929882
# Epoch 1: loss 0.3028650309943475
# Epoch 2: loss 0.25068326809959957
# Epoch 3: loss 0.2154005264501436
# Epoch 4: loss 0.18704874340391836
# Epoch 5: loss 0.16951858227569344
# Epoch 6: loss 0.15766482129339923
# Epoch 7: loss 0.14737495458662792
# Epoch 8: loss 0.140998157703481
# Epoch 9: loss 0.13475921170971406
# Epoch 10: loss 0.1288903514320534
# Epoch 11: loss 0.12467235012500771
# Test MRR 0.06230609093378411 val MRR 0.06725846290579797
# Evaluating {'residual': True, 'num_layers': 5, 'nonlinearity': 'relu', 'n_iter': 19, 'loss': 'adaptive_hinge', 'learning_rate': 0.001, 'l2': 0.0, 'kernel_width': 5, 'embedding_dim': 128, 'dilation_multiplier': 1, 'batch_size': 8, 'dilation': [1, 1, 1, 1, 1]}
# Epoch 0: loss 0.6953284093372604
# Epoch 1: loss 0.47120614100012853
# Epoch 2: loss 0.4176161061888217
# Epoch 3: loss 0.39287676354792683
# Epoch 4: loss 0.3752128235933755
# Epoch 5: loss 0.36429397402138547
# Epoch 6: loss 0.3549873616798879
# Epoch 7: loss 0.3444189977667136
# Epoch 8: loss 0.3353690161999851
# Epoch 9: loss 0.32884689206955126
# Epoch 10: loss 0.32093594803537967
# Epoch 11: loss 0.315822627949091
# Epoch 12: loss 0.3086466023811404
# Epoch 13: loss 0.3048096728842267
# Epoch 14: loss 0.2985332672009145
# Epoch 15: loss 0.2934407084188053
# Epoch 16: loss 0.28866552243476534
# Epoch 17: loss 0.2842574491299574
# Epoch 18: loss 0.2799334678085749
# Test MRR 0.07450299956671051 val MRR 0.06715436698850966
# Evaluating {'residual': True, 'num_layers': 8, 'nonlinearity': 'tanh', 'n_iter': 8, 'loss': 'pointwise', 'learning_rate': 0.1, 'l2': 1e-05, 'kernel_width': 5, 'embedding_dim': 128, 'dilation_multiplier': 2, 'batch_size': 16, 'dilation': [1, 2, 4, 8, 16, 32, 64, 128]}
# Epoch 0: loss 0.827702474282643
# Epoch 1: loss 0.9545277633179962
# Epoch 2: loss 0.9714826638511694
# Epoch 3: loss 0.9737687081169346
# Epoch 4: loss 0.9771042284942862
# Epoch 5: loss 0.9799028255594031
# Epoch 6: loss 0.9809078892732742
# Epoch 7: loss 0.9843061825441918
# Test MRR 0.004011795703814845 val MRR 0.006192119655196611
# Evaluating {'residual': True, 'num_layers': 9, 'nonlinearity': 'tanh', 'n_iter': 9, 'loss': 'pointwise', 'learning_rate': 0.001, 'l2': 1e-05, 'kernel_width': 7, 'embedding_dim': 8, 'dilation_multiplier': 1, 'batch_size': 16, 'dilation': [1, 1, 1, 1, 1, 1, 1, 1, 1]}
# Epoch 0: loss 0.6216577005499615
# Epoch 1: loss 0.5232206393307575
# Epoch 2: loss 0.5168435994774598
# Epoch 3: loss 0.5101351282092568
# Epoch 4: loss 0.48582919568460514
# Epoch 5: loss 0.45920054179189324
# Epoch 6: loss 0.43647865607732833
# Epoch 7: loss 0.42215702468595706
# Epoch 8: loss 0.41354136866231994
# Test MRR 0.013244097148860717 val MRR 0.010515753319083117
# Evaluating {'residual': True, 'num_layers': 7, 'nonlinearity': 'relu', 'n_iter': 18, 'loss': 'bpr', 'learning_rate': 0.01, 'l2': 0.0001, 'kernel_width': 3, 'embedding_dim': 16, 'dilation_multiplier': 1, 'batch_size': 16, 'dilation': [1, 1, 1, 1, 1, 1, 1]}
# Epoch 0: loss 0.2739570859350671
# Epoch 1: loss 0.226687911004182
# Epoch 2: loss 0.2092536693868048
# Epoch 3: loss 0.2049962715411696
# Epoch 4: loss 0.20248494550337984
# Epoch 5: loss 0.20143045329283082
# Epoch 6: loss 0.20342982413508262
# Epoch 7: loss 0.20498685404268976
# Epoch 8: loss 0.20519021542791516
# Epoch 9: loss 0.20366986771943735
# Epoch 10: loss 0.20197208905304978
# Epoch 11: loss 0.20092086883310467
# Epoch 12: loss 0.20141855321134355
# Epoch 13: loss 0.2029785842340519
# Epoch 14: loss 0.20204313403778573
# Epoch 15: loss 0.20109574917942782
# Epoch 16: loss 0.20315648647215473
# Epoch 17: loss 0.20412779261408961
# Test MRR 0.012589036597641039 val MRR 0.01075694073527122
# Evaluating {'residual': False, 'num_layers': 1, 'nonlinearity': 'tanh', 'n_iter': 17, 'loss': 'pointwise', 'learning_rate': 0.01, 'l2': 1e-05, 'kernel_width': 5, 'embedding_dim': 16, 'dilation_multiplier': 1, 'batch_size': 32, 'dilation': [1]}
# Epoch 0: loss 0.5816320252926994
# Epoch 1: loss 0.5214267024214234
# Epoch 2: loss 0.48263380454049853
# Epoch 3: loss 0.44974632299906836
# Epoch 4: loss 0.4312351631327263
# Epoch 5: loss 0.42615707931925334
# Epoch 6: loss 0.4212504123906954
# Epoch 7: loss 0.4168128307679253
# Epoch 8: loss 0.41234959259417386
# Epoch 9: loss 0.40726689803656807
# Epoch 10: loss 0.40428675026125255
# Epoch 11: loss 0.3998470639730517
# Epoch 12: loss 0.395474628955832
# Epoch 13: loss 0.39066824542967626
# Epoch 14: loss 0.3863416595199097
# Epoch 15: loss 0.38177973144992267
# Epoch 16: loss 0.3786340443443913
# Test MRR 0.024959454881697096 val MRR 0.02541581426504211
# Evaluating {'residual': True, 'num_layers': 7, 'nonlinearity': 'relu', 'n_iter': 9, 'loss': 'pointwise', 'learning_rate': 0.001, 'l2': 0.001, 'kernel_width': 7, 'embedding_dim': 128, 'dilation_multiplier': 2, 'batch_size': 16, 'dilation': [1, 2, 4, 8, 16, 32, 64]}
# Epoch 0: loss 0.5730361489671992
# Epoch 1: loss 0.5593893397024295
# Epoch 2: loss 0.5505679994467602
# Epoch 3: loss 0.5454119520345946
# Epoch 4: loss 0.5408985960228709
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Volumes/Guess_What/MIT_coursework/9417/9417-assignment/movielens_sequence.py in <module>()
#     301     mode = 'cnn'
#     302
# --> 303     run(train, test, validation, random_state, mode)
#
# /Volumes/Guess_What/MIT_coursework/9417/9417-assignment/movielens_sequence.py in run(train, test, validation, ranomd_state, model_type)
#     264                                        test,
#     265                                        validation,
# --> 266                                        random_state)
#     267
#     268         print('Test MRR {} val MRR {}'.format(
#
# /Volumes/Guess_What/MIT_coursework/9417/9417-assignment/movielens_sequence.py in evaluate_cnn_model(hyperparameters, train, test, validation, random_state)
#     182                                   random_state=random_state)
#     183
# --> 184     model.fit(train, verbose=True)
#     185
#     186     test_mrr = sequence_mrr_score(model, test)
#
# ~/anaconda3/lib/python3.6/site-packages/spotlight/sequence/implicit.py in fit(self, interactions, verbose)
#     229
#     230                 user_representation, _ = self._net.user_representation(
# --> 231                     sequence_var
#     232                 )
#     233
#
# ~/anaconda3/lib/python3.6/site-packages/spotlight/sequence/representations.py in user_representation(self, item_sequences)
#     398         x = F.pad(sequence_embeddings,
#     399                   (0, 0, receptive_field_width, 0))
# --> 400         x = self.nonlinearity(self.cnn_layers[0](x))
#     401
#     402         if self.residual_connections:
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# KeyboardInterrupt:

# %%
import torch

from spotlight.sequence.implicit import ImplicitSequenceModel
from spotlight.sequence.representations import CNNNet
from spotlight.evaluation import sequence_mrr_score


net = CNNNet(train.num_items,
             embedding_dim=hyperparameters['embedding_dim'],
             kernel_width=hyperparameters['kernel_width'],
             dilation=hyperparameters['dilation'],
             num_layers=hyperparameters['num_layers'],
             nonlinearity=hyperparameters['nonlinearity'],
             residual_connections=hyperparameters['residual'])

model = ImplicitSequenceModel(loss=hyperparameters['loss'],
                              representation=net,
                              batch_size=hyperparameters['batch_size'],
                              learning_rate=hyperparameters['learning_rate'],
                              l2=hyperparameters['l2'],
                              n_iter=hyperparameters['n_iter'],
                              use_cuda=torch.cuda.is_available(),
                              random_state=random_state)

model.fit(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-6b37d52dcc00> in <module>()
#       7
#       8 net = CNNNet(train.num_items,
# ----> 9              embedding_dim=hyperparameters['embedding_dim'],
#      10              kernel_width=hyperparameters['kernel_width'],
#      11              dilation=hyperparameters['dilation'],
#
# NameError: name 'hyperparameters' is not defined

# %%
test_mrr = sequence_mrr_score(model, test)
val_mrr = sequence_mrr_score(model, validation)

# %%
from spotlight.evaluation import rmse_score
train_rmse = rmse_score(model, train)
test_rmse = rmse_score(model, test)
print('Train RMSE {:.3f}, test RMSE {:.3f}'.format(train_rmse, test_rmse))
