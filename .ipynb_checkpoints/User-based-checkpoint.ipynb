# %% [markdown]
# # User-Based recommend system

# %%
import pandas as pd
import copy as cp

# %%
data = pd.read_csv('./ml-latest-small/ratings.csv')
data = data[['userId', 'movieId','rating']]

# %% [markdown]
# ### Train test split
# For each user in all users, select fixed portion of movies he watched as train set and the rest as test set.

# %%
def train_test_split(data, seed = 6, portion = 0.8):
    train_set = {}
    test_set = {}
    for user, movies in data.groupby('userId'):
        movies = movies.sample(frac=1, random_state=seed).reset_index(drop=True)
        train = movies[:int(portion*len(movies))]
        test = movies[int(portion*len(movies)):]
        train_set[user] = train[['movieId', 'rating']]
        test_set[user] = test[['movieId', 'rating']]
    #print('Data preparation finished')
    return train_set, test_set

# %%
def itemUserAndRating(train_set):
    item_user = {}
    rating = {}
    for u, items in train_set.items():
        rating[u] = {}
        movies = items['movieId'].tolist()
        ratings = items['rating'].tolist()
        for inum in range(len(movies)):
            i = movies[inum]
            rating[u][i] = ratings[inum]
            if i not in item_user.keys():
                item_user[i] = set()
            item_user[i].add(u)
    return item_user, rating


# the number of actual seen movie
print(len(itemUserAndRating(train_set)[0]))
# Out:
# 8915

# %% [markdown]
# ### User-base theory
# 1. Caculate the matrix of user similarity based on cosin similarity
# 2. For a specific combination of user and item, (u, i), in all the other users who watched movie i, choose the top K most similar users to the use u.
# 3. Predict the score for such combination based on those top K similar users.

# %%
from operator import itemgetter
import numpy as np

def User_Similarity(train_set):
    N = {}
    C = {}
    W = {}
    for u, u_movie in train_set.items():
        N[u] = u_movie.shape[0]
        C[u] = {}
        W[u] = {}
        for v in train_set.keys():
            C[u][v] = 0
            W[u][v] = 0
    # Build inverse table
    item_user, rating = itemUserAndRating(train_set)
    for i, users in item_user.items():
        for u in users:
            for v in users:
                if v != u:
                    urating = rating[u][i]
                    vrating = rating[v][i]
                    corating = -abs(urating - vrating) + 5
                    C[u][v] += 1/np.log(1+len(users)*1.0) * corating
    
    # Calculate similarity matrix
    for u, related_users in C.items():
        for v, cuv in related_users.items():
            W[u][v] = cuv/(N[u]*N[v])**0.5
    print('user similarity finished')
    return W

# %% [markdown]
# Predict all the possible ratings

# %%
def predict(train_set, K, user_sim):
    # store the original ratings
    item_user, orig_ratings = itemUserAndRating(train_set)

    predict_ratings = cp.copy(orig_ratings)
    for u, wu in user_sim.items():  # u is the user, wu is the user similarity list of u
        # already_items is the movies already watched by u
        already_items = train_set[u]['movieId'].tolist()
        for item, vs in item_user.items():  # item is some movie, vs is the list of peopele who watched this movie
            if item not in already_items:
                # friendNum is the total amount of users we can use to predict for u with movie item
                friendNum = min(K, len(vs))
                wuv = [(v, wu[v]) for v in vs]
                topv = sorted(wuv, key=itemgetter(1), reverse=True)[
                    :friendNum]  # topv store the v id and wuv
                sum_wuv = sum([_[1] for _ in topv])
                if sum_wuv == 0:
                    #nobody wathced this movie
                    continue
                topv_normal = [(_[0], _[1]/sum_wuv)
                               for _ in topv]  # normalise the similarity
                if item not in predict_ratings[u]:
                    predict_ratings[u][item] = 0
                for v in topv_normal:
                    # the predict rating is the sum of product of related users's ratings and his similarity
                    predict_ratings[u][item] += orig_ratings[v[0]][item] * v[1]
        predict_ratings[u] = sorted(predict_ratings[u].items(), key = itemgetter(0))
    return predict_ratings

# %%
def rmse(predict, real):
    return np.sqrt(np.mean((predict-real)**2))

# %%
# get the performance score of the predictions
def get_score(predictions, test_set):
    rmselist = []
    for user in test_set.keys():
        prediction = pd.DataFrame(predictions[user], columns=['movieId', user])
        test = test_set[user]
        merge = pd.merge(prediction, test)
        user_error = rmse(merge[user], merge['rating'])
        print(f"For user {user}, test error = {user_error}")
        rmselist.append(user_error)
    return np.mean(rmselist)

# %%
def score2(predictions, test_set):
    predict = []
    real = []
    for user, test_df in test_set.items():
        test_score = test_df.set_index('movieId')
        #print(test_score)
        test_movies = set(test_df['movieId'].tolist())
        #print(test_movies)
        for movie_score in predictions[user]:
            movie, score = movie_score
            if movie in test_movies:
                predict.append(score)
                real.append(test_score.at[movie, 'rating'])
    predict=np.array(predict)
    real=np.array(real)
    return rmse(predict, real)

# %% [markdown]
# Let's test the model and get the rmse score

# %%
train_set, test_set = train_test_split(data)
user_similarity = User_Similarity(train_set)
predictions = predict(train_set, K = 20)
print(score(predictions, test_set))
# Out:
# 0.9460420702603404

# %% [markdown]
# Let's do the cross validation and get a more convinceble error and variance.

# %%
def cross_validation(data, fold = 5, K = 20):
    score_list = []
    for seed in range(fold):
        train_set, test_set = train_test_split(data, seed)
        user_similarity = User_Similarity(train_set)
        predictions = predict(train_set, K, user_similarity)
        test_score = score2(predictions, test_set)
        print(f"test:{seed}, rmse is {test_score}.")
        score_list.append(test_score)
    return np.mean(score_list), np.var(score_list,ddof=1)

# %%
print(cross_validation(data))
# Out:
# user similarity finished
# test:0, rmse is 0.9567780561385532.
# user similarity finished
# test:1, rmse is 0.9533116750080879.
# user similarity finished
# test:2, rmse is 0.9457387881316458.
# user similarity finished
# test:3, rmse is 0.9576049759350262.
# user similarity finished
# test:4, rmse is 0.9542873487926912.
# (0.9535441688012009, 2.211962978726651e-05)

# %% [markdown]
# Let's see how will the score change if we modify the K values

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

train_set, test_set = train_test_split(data)
error = []
x = []
user_similarity = User_Similarity(train_set)
for K in range(1, 16, 2):
    predictions = predict(train_set, K, user_similarity)
    test_score = get_score(predictions, test_set)
    print(f"K:{K}, rmse is {test_score}.")
    error.append(test_score)
    x.append(K)
plt.plot(x, error)
plt.xlabel('K')
plt.ylabel('rmse error')
plt.show()
# Out:
# user similarity finished
# For user 1, test error = 1.5740958604156794
# For user 2, test error = 1.3038404810405297
# For user 3, test error = 3.1770662567847086
# For user 4, test error = 1.4142135623730951
# For user 5, test error = 1.4529663145135578
# For user 6, test error = 1.0356546939792675
# For user 7, test error = 1.4719601443879744
# For user 8, test error = 1.3038404810405297
# For user 9, test error = 1.118033988749895
# For user 10, test error = 1.5
# For user 11, test error = 1.4142135623730951
# For user 12, test error = 1.3758114488755873
# For user 13, test error = 0.6546536707079771
# For user 14, test error = 1.224744871391589
# For user 15, test error = 0.8660254037844386
# For user 16, test error = 1.0723805294763609
# For user 17, test error = 0.8930952063576691
# For user 18, test error = 0.816496580927726
# For user 19, test error = 1.2321184772695302
# For user 20, test error = 1.58607219255619
# For user 21, test error = 1.2729815111425788
# For user 22, test error = 2.071633815776009
# For user 23, test error = 0.938083151964686
# For user 24, test error = 0.7229988054812212
# For user 25, test error = 0.2041241452319315
# For user 26, test error = 2.0976176963403033
# For user 27, test error = 1.2480754415067656
# For user 28, test error = 1.1918727900508306
# For user 29, test error = 1.1114378604524227
# For user 30, test error = 1.0522085616183026
# For user 31, test error = 1.4832396974191326
# For user 32, test error = 0.9258200997725514
# For user 33, test error = 1.1110243021644486
# For user 34, test error = 1.20761472884912
# For user 35, test error = 1.4142135623730951
# For user 36, test error = 1.4505745987941008
# For user 37, test error = 1.0954451150103321
# For user 38, test error = 1.3693063937629153
# For user 39, test error = 1.14564392373896
# For user 40, test error = 1.3318444067568567
# For user 41, test error = 1.541103500742244
# For user 42, test error = 1.3131762327204288
# For user 43, test error = 1.3513278493843524
# For user 44, test error = 1.4907119849998598
# For user 45, test error = 1.4053469322555197
# For user 46, test error = 1.1547005383792515
# For user 47, test error = 1.337333742362593
# For user 48, test error = 1.0690449676496976
# For user 49, test error = 1.0723805294763609
# For user 50, test error = 1.1726039399558574
# For user 51, test error = 1.4278418660223537
# For user 52, test error = 0.8660254037844386
# For user 53, test error = 2.9154759474226504
# For user 54, test error = 1.1338934190276817
# For user 55, test error = 1.3601470508735443
# For user 56, test error = 1.0488088481701516
# For user 57, test error = 1.0777097630314636
# For user 58, test error = 1.681096950363583
# For user 59, test error = 1.1338934190276817
# For user 60, test error = 0.8366600265340756
# For user 61, test error = 0.770551750371122
# For user 62, test error = 0.8301741920760902
# For user 63, test error = 1.2379044419531773
# For user 64, test error = 1.2109278070331666
# For user 65, test error = 0.7559289460184544
# For user 66, test error = 1.137592917989042
# For user 67, test error = 1.2374368670764582
# For user 68, test error = 1.275565018218389
# For user 69, test error = 0.8366600265340756
# For user 70, test error = 0.7071067811865476
# For user 71, test error = 0.9258200997725514
# For user 72, test error = 0.6666666666666666
# For user 73, test error = 1.1449784320047682
# For user 74, test error = 0.7464200272921789
# For user 75, test error = 1.5698043554168508
# For user 76, test error = 1.811797090088229
# For user 77, test error = 1.9148542155126762
# For user 78, test error = 1.6466749714313573
# For user 79, test error = 0.9198662110077999
# For user 80, test error = 0.8660254037844386
# For user 81, test error = 1.6832508230603465
# For user 82, test error = 0.9682458365518543
# For user 83, test error = 1.3110110602126894
# For user 84, test error = 1.1753109938239283
# For user 85, test error = 1.3758114488755873
# For user 86, test error = 0.7196229171289245
# For user 87, test error = 0.9486832980505138
# For user 88, test error = 0.8036375634160796
# For user 89, test error = 1.797264234930059
# For user 90, test error = 0.9486832980505138
# For user 91, test error = 1.1645308392102367
# For user 92, test error = 0.8660254037844386
# For user 93, test error = 1.3601470508735443
# For user 94, test error = 1.5
# For user 95, test error = 0.958706236059213
# For user 96, test error = 1.334634781503914
# For user 97, test error = 0.9519716382329886
# For user 98, test error = 1.1002392084403616
# For user 99, test error = 1.7580981459830651
# For user 100, test error = 1.1583033569262702
# For user 101, test error = 1.278520779891897
# For user 102, test error = 1.1547005383792515
# For user 103, test error = 1.130388330520878
# For user 104, test error = 1.2172995448196726
# For user 105, test error = 0.8710751573914627
# For user 106, test error = 0.9636241116594315
# For user 107, test error = 1.2535663410560174
# For user 108, test error = 1.541103500742244
# For user 109, test error = 1.0
# For user 110, test error = 0.8366600265340756
# For user 111, test error = 1.1820835116739548
# For user 112, test error = 1.0919284281983377
# For user 113, test error = 1.390443574307614
# For user 114, test error = 0.6123724356957945
# For user 115, test error = 1.3987572123604706
# For user 116, test error = 1.6457014715109584
# For user 117, test error = 0.9211323729436766
# For user 118, test error = 1.161895003862225
# For user 119, test error = 1.2196310917650468
# For user 120, test error = 1.0
# For user 121, test error = 0.7071067811865476
# For user 122, test error = 1.0394750956979544
# For user 123, test error = 0.9013878188659973
# For user 124, test error = 0.8215838362577492
# For user 125, test error = 1.1599949289950011
# For user 126, test error = 1.3693063937629153
# For user 127, test error = 2.3979157616563596
# For user 128, test error = 1.0177004891982149
# For user 129, test error = 0.9354143466934853
# For user 130, test error = 1.2909944487358056
# For user 131, test error = 0.6813851438692469
# For user 132, test error = 1.0784449352010836
# For user 133, test error = 1.0177004891982149
# For user 134, test error = 1.558387444947959
# For user 135, test error = 1.19335960332883
# For user 136, test error = 1.3021720984236467
# For user 137, test error = 0.9258200997725514
# For user 138, test error = 2.202271554554524
# For user 139, test error = 1.6832508230603465
# For user 140, test error = 1.0377490433255416
# For user 141, test error = 1.147247344990711
# For user 142, test error = 1.2747548783981961
# For user 143, test error = 1.927248223318863
# For user 144, test error = 0.9903379376602871
# For user 145, test error = 1.4142135623730951
# For user 146, test error = 0.8864052604279183
# For user 147, test error = 1.9364916731037085
# For user 148, test error = 0.9354143466934853
# For user 149, test error = 1.848422751068236
# For user 150, test error = 1.0801234497346435
# For user 151, test error = 1.3844373104863459
# For user 152, test error = 1.1519214716824566
# For user 153, test error = 1.8727928185403933
# For user 154, test error = 1.0350983390135313
# For user 155, test error = 1.0
# For user 156, test error = 1.1613286401903278
# For user 157, test error = 1.3601470508735443
# For user 158, test error = 1.2041594578792296
# For user 159, test error = 1.6085707942145413
# For user 160, test error = 1.6608801062306475
# For user 161, test error = 1.2374368670764582
# For user 162, test error = 0.9354143466934853
# For user 163, test error = 0.7745966692414834
# For user 164, test error = 1.4684175155588413
# For user 165, test error = 0.9198662110077999
# For user 166, test error = 0.9176629354822471
# For user 167, test error = 1.3666188418222285
# For user 168, test error = 0.6123724356957945
# For user 169, test error = 1.058475493514314
# For user 170, test error = 1.0954451150103321
# For user 171, test error = 1.1440382552221602
# For user 172, test error = 0.8660254037844386
# For user 173, test error = 0.6324555320336759
# For user 174, test error = 1.1019463300386794
# For user 175, test error = 1.9621416870348585
# For user 176, test error = 1.224744871391589
# For user 177, test error = 1.0928337999374445
# For user 178, test error = 0.9519716382329886
# For user 179, test error = 0.8017837257372732
# For user 180, test error = 0.3872983346207417
# For user 181, test error = 1.241638702145945
# For user 182, test error = 1.1923177519527342
# For user 183, test error = 0.9574271077563381
# For user 184, test error = 1.292692009559488
# For user 185, test error = 1.51657508881031
# For user 186, test error = 1.2649110640673518
# For user 187, test error = 1.2208130960079906
# For user 188, test error = 1.51657508881031
# For user 189, test error = 0.6614378277661477
# For user 190, test error = 0.7676494735787385
# For user 191, test error = 1.5612494995995996
# For user 192, test error = 1.3416407864998738
# For user 193, test error = 1.2100767390069582
# For user 194, test error = 1.0307764064044151
# For user 195, test error = 1.2486835172756103
# For user 196, test error = 1.0690449676496976
# For user 197, test error = 2.0354009783964297
# For user 198, test error = 1.5162166875081744
# For user 199, test error = 1.1414100496352968
# For user 200, test error = 1.0806990551310731
# For user 201, test error = 1.0498917693137362
# For user 202, test error = 0.9953596037316065
# For user 203, test error = 0.7264831572567789
# For user 204, test error = 0.75
# For user 205, test error = 0.8660254037844386
# For user 206, test error = 0.8944271909999159
# For user 207, test error = 2.0615528128088303
# For user 208, test error = 1.5811388300841898
# For user 209, test error = 1.3093073414159542
# For user 210, test error = 0.9899494936611666
# For user 211, test error = 1.118033988749895
# For user 212, test error = 1.1134612334371354
# For user 213, test error = 0.6416889479197478
# For user 214, test error = 1.1832159566199232
# For user 215, test error = 1.02469507659596
# For user 216, test error = 1.2468710839537502
# For user 217, test error = 1.1943494414262914
# For user 218, test error = 1.7440374613713625
# For user 219, test error = 0.9574271077563381
# For user 220, test error = 1.3251783128981585
# For user 221, test error = 1.024325350776024
# For user 222, test error = 1.087332362558324
# For user 223, test error = 1.2535663410560174
# For user 224, test error = 1.1381803659589922
# For user 225, test error = 1.2909944487358056
# For user 226, test error = 1.0012618301549563
# For user 227, test error = 0.7071067811865476
# For user 228, test error = 1.5491933384829668
# For user 229, test error = 1.1435437497937313
# For user 230, test error = 1.566430242207965
# For user 231, test error = 1.3601470508735443
# For user 232, test error = 0.9239364353597956
# For user 233, test error = 1.2747548783981961
# For user 234, test error = 1.6545392107774297
# For user 235, test error = 0.9198662110077999
# For user 236, test error = 1.4142135623730951
# For user 237, test error = 1.0488088481701516
# For user 238, test error = 1.3228756555322954
# For user 239, test error = 1.1100193048514324
# For user 240, test error = 1.255755978254962
# For user 241, test error = 1.0606601717798212
# For user 242, test error = 1.1338934190276817
# For user 243, test error = 1.4142135623730951
# For user 244, test error = 1.2617865362880898
# For user 245, test error = 1.70293863659264
# For user 246, test error = 1.076353373834938
# For user 247, test error = 1.0954451150103321
# For user 248, test error = 0.9293203772845852
# For user 249, test error = 0.9128709291752769
# For user 250, test error = 1.0408329997330663
# For user 251, test error = 0.7071067811865476
# For user 252, test error = 1.0458250331675945
# For user 253, test error = 1.0540925533894598
# For user 254, test error = 1.1519214716824566
# For user 255, test error = 2.721442632134655
# For user 256, test error = 1.282161999881214
# For user 257, test error = 1.479019945774904
# For user 258, test error = 1.0954451150103321
# For user 259, test error = 2.071633815776009
# For user 260, test error = 1.4283986070579744
# For user 261, test error = 0.7977240352174656
# For user 262, test error = 1.2583057392117916
# For user 263, test error = 0.8486684247915055
# For user 264, test error = 1.4860462083439174
# For user 265, test error = 1.0408329997330663
# For user 266, test error = 1.3522468075656264
# For user 267, test error = 1.0
# For user 268, test error = 1.4344658614593473
# For user 269, test error = 1.632993161855452
# For user 270, test error = 1.541103500742244
# For user 271, test error = 1.4433756729740645
# For user 272, test error = 0.9636241116594315
# For user 273, test error = 1.1281521496355325
# For user 274, test error = 1.0696186093489815
# For user 275, test error = 1.270289873862011
# For user 276, test error = 0.6666666666666666
# For user 277, test error = 0.7071067811865476
# For user 278, test error = 1.0606601717798212
# For user 279, test error = 0.982485510212633
# For user 280, test error = 1.1752659273543158
# For user 281, test error = 0.8944271909999159
# For user 282, test error = 0.8416254115301732
# For user 283, test error = 0.6546536707079771
# For user 284, test error = 1.1547005383792515
# For user 285, test error = 0.8451542547285166
# For user 286, test error = 0.9354143466934853
# For user 287, test error = 1.6607421582319852
# For user 288, test error = 1.0054995831748046
# For user 289, test error = 0.82915619758885
# For user 290, test error = 0.9881371839677032
# For user 291, test error = 1.2535663410560174
# For user 292, test error = 1.0827805840074194
# For user 293, test error = 1.2041594578792296
# For user 294, test error = 1.3543641776056377
# For user 295, test error = 1.7716909687891083
# For user 296, test error = 0.45643546458763845
# For user 297, test error = 1.3416407864998738
# For user 298, test error = 1.6203959578168816
# For user 299, test error = 1.0954451150103321
# For user 300, test error = 1.4638501094227998
# For user 301, test error = 1.2379857412959867
# For user 302, test error = 0.8451542547285166
# For user 303, test error = 0.9534625892455924
# For user 304, test error = 1.3588932662615225
# For user 305, test error = 1.0783685770082452
# For user 306, test error = 1.1381803659589922
# For user 307, test error = 1.1785743222873473
# For user 308, test error = 1.9588150810475016
# For user 309, test error = 0.7433919416750282
# For user 310, test error = 1.8292495308606331
# For user 311, test error = 1.9364916731037085
# For user 312, test error = 1.0723805294763609
# For user 313, test error = 1.332567181840243
# For user 314, test error = 0.8987170342729172
# For user 315, test error = 1.0522085616183026
# For user 316, test error = 1.296849328880646
# For user 317, test error = 1.340633170295774
# For user 318, test error = 0.952415137739103
# For user 319, test error = 1.1801936887041646
# For user 320, test error = 0.8660254037844386
# For user 321, test error = 1.0
# For user 322, test error = 1.5300029708824394
# For user 323, test error = 1.2599603168354152
# For user 324, test error = 1.0606601717798212
# For user 325, test error = 0.9040507133494737
# For user 326, test error = 1.118033988749895
# For user 327, test error = 1.5732132722552274
# For user 328, test error = 1.7377018855768256
# For user 329, test error = 2.165063509461097
# For user 330, test error = 1.0677078252031311
# For user 331, test error = 1.071008320943125
# For user 332, test error = 0.951661902861773
# For user 333, test error = 1.51657508881031
# For user 334, test error = 0.7777137710478189
# For user 335, test error = 1.0408329997330663
# For user 336, test error = 1.6583123951777
# For user 337, test error = 1.0307764064044151
# For user 338, test error = 1.7728105208558367
# For user 339, test error = 0.7599110400121809
# For user 340, test error = 1.4142135623730951
# For user 341, test error = 1.1067971810589328
# For user 342, test error = 1.5750457868802517
# For user 343, test error = 1.0801234497346435
# For user 344, test error = 0.8556534679079242
# For user 345, test error = 1.3768926368215255
# For user 346, test error = 0.8705242673240075
# For user 347, test error = 1.0
# For user 348, test error = 1.3314380468978917
# For user 349, test error = 1.0606601717798212
# For user 350, test error = 0.8660254037844386
# For user 351, test error = 0.9077852576871218
# For user 352, test error = 0.9655068046526178
# For user 353, test error = 1.0
# For user 354, test error = 1.0081192131023429
# For user 355, test error = 1.1547005383792515
# For user 356, test error = 1.0773645092141684
# For user 357, test error = 0.8260946873285365
# For user 358, test error = 1.1055415967851334
# For user 359, test error = 0.8660254037844386
# For user 360, test error = 1.7888543819998317
# For user 361, test error = 1.3416407864998738
# For user 362, test error = 0.8725615372932939
# For user 363, test error = 1.466287829861518
# For user 364, test error = 1.0954451150103321
# For user 365, test error = 1.4304881321759704
# For user 366, test error = 1.1338934190276817
# For user 367, test error = 1.30487650860252
# For user 368, test error = 0.9260274735235614
# For user 369, test error = 1.139331787969125
# For user 370, test error = 1.2875926129184283
# For user 371, test error = 0.9428090415820634
# For user 372, test error = 1.1086778913041726
# For user 373, test error = 1.4142135623730951
# For user 374, test error = 0.9258200997725514
# For user 375, test error = 1.3228756555322954
# For user 376, test error = 1.3123346456686351
# For user 377, test error = 1.200198396297958
# For user 378, test error = 0.9082951062292475
# For user 379, test error = 1.4142135623730951
# For user 380, test error = 0.9797738055065108
# For user 381, test error = 0.9094655900991901
# For user 382, test error = 1.0779782173295698
# For user 383, test error = 1.3758114488755873
# For user 384, test error = 0.8128433340529315
# For user 385, test error = 1.0848176198295651
# For user 386, test error = 0.8017837257372732
# For user 387, test error = 1.0919745312796223
# For user 388, test error = 0.75
# For user 389, test error = 1.2535663410560174
# For user 390, test error = 1.3228756555322954
# For user 391, test error = 1.2326721054199772
# For user 392, test error = 1.5491933384829668
# For user 393, test error = 1.4106735979665885
# For user 394, test error = 1.0954451150103321
# For user 395, test error = 1.4142135623730951
# For user 396, test error = 0.7637626158259734
# For user 397, test error = 0.8366600265340756
# For user 398, test error = 0.9082951062292475
# For user 399, test error = 2.1065374432940898
# For user 400, test error = 1.0801234497346435
# For user 401, test error = 0.7187952884282609
# For user 402, test error = 0.7745966692414834
# For user 403, test error = 0.6813851438692469
# For user 404, test error = 0.816496580927726
# For user 405, test error = 0.8118441408859887
# For user 406, test error = 1.8540496217739157
# For user 407, test error = 0.806225774829855
# For user 408, test error = 1.1926499038290526
# For user 409, test error = 1.216868616888952
# For user 410, test error = 1.1902380714238083
# For user 411, test error = 0.9405399431259602
# For user 412, test error = 1.4679107277903192
# For user 413, test error = 1.6708281379802852
# For user 414, test error = 1.0897247358851685
# For user 415, test error = 0.7608859102526822
# For user 416, test error = 1.0975178606954215
# For user 417, test error = 1.1417405259389843
# For user 418, test error = 1.5217718205053643
# For user 419, test error = 1.137147065368355
# For user 420, test error = 0.8277591347639633
# For user 421, test error = 0.9519716382329886
# For user 422, test error = 1.2018504251546631
# For user 423, test error = 1.9235384061671346
# For user 424, test error = 1.0844011831079519
# For user 425, test error = 0.9687747881545713
# For user 426, test error = 0.9428090415820634
# For user 427, test error = 1.3284223283101428
# For user 428, test error = 1.224744871391589
# For user 429, test error = 0.5
# For user 430, test error = 1.070436048222094
# For user 431, test error = 1.8371173070873836
# For user 432, test error = 1.103970108290981
# For user 433, test error = 1.466287829861518
# For user 434, test error = 1.372216718818225
# For user 435, test error = 1.092906420717
# For user 436, test error = 0.9293203772845852
# For user 437, test error = 1.2165525060596438
# For user 438, test error = 0.9643650760992956
# For user 439, test error = 2.0248456731316584
# For user 440, test error = 0.944911182523068
# For user 441, test error = 1.4240006242195884
# For user 442, test error = 2.0615528128088303
# For user 443, test error = 1.0458250331675945
# For user 444, test error = 1.0
# For user 445, test error = 0.9185586535436918
# For user 446, test error = 0.8043996665398437
# For user 447, test error = 1.3228756555322954
# For user 448, test error = 1.1387367173650853
# For user 449, test error = 1.648863244784115
# For user 450, test error = 1.0975178606954215
# For user 451, test error = 1.0
# For user 452, test error = 1.5597842252274168
# For user 453, test error = 1.3722479790945339
# For user 454, test error = 0.8819171036881969
# For user 455, test error = 0.7071067811865476
# For user 456, test error = 0.8819171036881969
# For user 457, test error = 1.449137674618944
# For user 458, test error = 1.35400640077266
# For user 459, test error = 0.7071067811865476
# For user 460, test error = 1.0145993123917847
# For user 461, test error = 1.8142950880897701
# For user 462, test error = 1.2008635104505871
# For user 463, test error = 0.9819805060619657
# For user 464, test error = 0.9525793444156804
# For user 465, test error = 1.0215078369104984
# For user 466, test error = 0.872278375988647
# For user 467, test error = 1.224744871391589
# For user 468, test error = 1.0
# For user 469, test error = 0.9545214042184236
# For user 470, test error = 0.8660254037844386
# For user 471, test error = 1.136515141415488
# For user 472, test error = 0.9128709291752769
# For user 473, test error = 0.770551750371122
# For user 474, test error = 0.9731019341783654
# For user 475, test error = 1.0356546939792675
# For user 476, test error = 0.6546536707079771
# For user 477, test error = 1.1716846109709758
# For user 478, test error = 1.0488088481701516
# For user 479, test error = 1.3363062095621219
# For user 480, test error = 1.1070050237913946
# For user 481, test error = 0.9258200997725514
# For user 482, test error = 1.5750457868802517
# For user 483, test error = 1.110925258321848
# For user 484, test error = 1.2095300587265134
# For user 485, test error = 1.0
# For user 486, test error = 1.5
# For user 487, test error = 1.4433756729740645
# For user 488, test error = 1.0268144068364822
# For user 489, test error = 1.4580755302687527
# For user 490, test error = 1.4885929903466195
# For user 491, test error = 0.8770580193070292
# For user 492, test error = 1.4
# For user 493, test error = 0.6793662204867574
# For user 494, test error = 1.0954451150103321
# For user 495, test error = 1.1875930946627158
# For user 496, test error = 0.7637626158259734
# For user 497, test error = 1.3228756555322954
# For user 498, test error = 1.6035674514745464
# For user 499, test error = 1.0206207261596576
# For user 500, test error = 1.8142950880897701
# For user 501, test error = 1.247219128924647
# For user 502, test error = 2.017778127403648
# For user 503, test error = 1.5087464298130697
# For user 504, test error = 0.9428090415820634
# For user 505, test error = 0.9819805060619657
# For user 506, test error = 1.7159383568311668
# For user 507, test error = 1.0954451150103321
# For user 508, test error = 1.7175564037317668
# For user 509, test error = 1.086174608844672
# For user 510, test error = 1.3939805659268776
# For user 511, test error = 0.6571287406727709
# For user 512, test error = 1.2649110640673518
# For user 513, test error = 0.823754471047914
# For user 514, test error = 1.1610223826322097
# For user 515, test error = 0.5773502691896257
# For user 516, test error = 1.2649110640673518
# For user 517, test error = 1.776346082666721
# For user 518, test error = 0.7071067811865476
# For user 519, test error = 1.1726039399558574
# For user 520, test error = 1.1470786693528088
# For user 521, test error = 0.8660254037844386
# For user 522, test error = 1.349263806863884
# For user 523, test error = 0.5
# For user 524, test error = 0.9622504486493763
# For user 525, test error = 1.08397416943394
# For user 526, test error = 0.6454972243679028
# For user 527, test error = 1.3500298682478438
# For user 528, test error = 1.347837774610382
# For user 529, test error = 1.0
# For user 530, test error = 0.7071067811865476
# For user 531, test error = 1.6278820596099706
# For user 532, test error = 1.1832159566199232
# For user 533, test error = 1.1801936887041646
# For user 534, test error = 1.0771231010229432
# For user 535, test error = 1.4142135623730951
# For user 536, test error = 1.7320508075688772
# For user 537, test error = 1.3133925536563698
# For user 538, test error = 1.3228756555322954
# For user 539, test error = 1.1858541225631423
# For user 540, test error = 1.5545631755148024
# For user 541, test error = 1.5634719199411433
# For user 542, test error = 1.5144234087168507
# For user 543, test error = 1.595893166850463
# For user 544, test error = 1.224744871391589
# For user 545, test error = 1.4142135623730951
# For user 546, test error = 1.6641005886756874
# For user 547, test error = 1.0954451150103321
# For user 548, test error = 1.02469507659596
# For user 549, test error = 1.4317821063276353
# For user 550, test error = 0.5916079783099616
# For user 551, test error = 0.9539392014169457
# For user 552, test error = 1.1556497375024466
# For user 553, test error = 0.7573172464461019
# For user 554, test error = 1.4240006242195884
# For user 555, test error = 1.3438019092963707
# For user 556, test error = 1.0856202966836188
# For user 557, test error = 1.1547005383792515
# For user 558, test error = 1.3307266185559425
# For user 559, test error = 1.3228756555322954
# For user 560, test error = 0.8100925873009825
# For user 561, test error = 1.1683321445547923
# For user 562, test error = 1.0
# For user 563, test error = 0.9933992677987828
# For user 564, test error = 1.3228756555322954
# For user 565, test error = 0.5773502691896257
# For user 566, test error = 0.9660917830792959
# For user 567, test error = 1.5799221012929232
# For user 568, test error = 1.91049731745428
# For user 569, test error = 1.224744871391589
# For user 570, test error = 0.7250110520819842
# For user 571, test error = 1.3128915456069918
# For user 572, test error = 0.8980265101338745
# For user 573, test error = 1.0062305898749053
# For user 574, test error = 0.7745966692414834
# For user 575, test error = 1.704772712123232
# For user 576, test error = 1.4577379737113252
# For user 577, test error = 0.9560661587986472
# For user 578, test error = 1.224744871391589
# For user 579, test error = 1.1832159566199232
# For user 580, test error = 1.2223124064851911
# For user 581, test error = 1.2119199643540823
# For user 582, test error = 0.9574271077563381
# For user 583, test error = 1.3149778198382918
# For user 584, test error = 1.6087993330796875
# For user 585, test error = 1.0
# For user 586, test error = 1.0465362369445672
# For user 587, test error = 1.695582495781317
# For user 588, test error = 1.0801234497346435
# For user 589, test error = 1.0
# For user 590, test error = 0.9238226430771596
# For user 591, test error = 1.4142135623730951
# For user 592, test error = 1.3377121081198773
# For user 593, test error = 1.2295953651119387
# For user 594, test error = 1.8787660590829036
# For user 595, test error = 1.224744871391589
# For user 596, test error = 0.8770580193070292
# For user 597, test error = 1.2050921919136461
# For user 598, test error = 1.9364916731037085
# For user 599, test error = 1.238518700475924
# For user 600, test error = 1.2831140163474828
# For user 601, test error = 1.0
# For user 602, test error = 1.0886621079036347
# For user 603, test error = 1.3415318118998079
# For user 604, test error = 0.9733285267845752
# For user 605, test error = 1.4341611422075908
# For user 606, test error = 0.9514531821875089
# For user 607, test error = 1.46352037631592
# For user 608, test error = 1.210434432404959
# For user 609, test error = 1.0
# For user 610, test error = 0.9013878188659973
# K:1, rmse is 1.1894368332114138.
# For user 1, test error = 1.195931878015445
# For user 2, test error = 1.1416658240338298
# For user 3, test error = 3.055196457213616
# For user 4, test error = 1.3376193015932314
# For user 5, test error = 1.4234222691843732
# For user 6, test error = 0.7984313496296351
# For user 7, test error = 1.4043892079427451
# For user 8, test error = 1.265426246152444
# For user 9, test error = 0.7510118950164201
# For user 10, test error = 1.32493620703715
# For user 11, test error = 1.1994843274669105
# For user 12, test error = 1.4566695234125595
# For user 13, test error = 0.6905898499718366
# For user 14, test error = 1.1026435109619894
# For user 15, test error = 0.9059234903048349
# For user 16, test error = 0.72359635492337
# For user 17, test error = 0.7455724740989902
# For user 18, test error = 0.6287789031957568
# For user 19, test error = 1.0504310407150876
# For user 20, test error = 1.228207407980555
# For user 21, test error = 1.0887233732425992
# For user 22, test error = 2.0222487785511927
# For user 23, test error = 0.8446796909493095
# For user 24, test error = 0.4892944900449166
# For user 25, test error = 0.3175178252837035
# For user 26, test error = 1.0966905840230763
# For user 27, test error = 1.1344625724568176
# For user 28, test error = 1.0967573413665885
# For user 29, test error = 0.6795674668384735
# For user 30, test error = 0.5467201743543211
# For user 31, test error = 1.4075605920237557
# For user 32, test error = 0.6845227259770544
# For user 33, test error = 0.9505141140797606
# For user 34, test error = 1.1528909326412082
# For user 35, test error = 0.9253956124447456
# For user 36, test error = 1.011040174674301
# For user 37, test error = 1.2174877112327216
# For user 38, test error = 1.3027692052873074
# For user 39, test error = 0.8728521392419619
# For user 40, test error = 1.0964777525841207
# For user 41, test error = 1.4874665520994421
# For user 42, test error = 1.177659779231464
# For user 43, test error = 1.3307289503278577
# For user 44, test error = 1.2214249958488252
# For user 45, test error = 1.1627986570773283
# For user 46, test error = 0.8976417827257076
# For user 47, test error = 1.2156561065440898
# For user 48, test error = 0.8868700759854459
# For user 49, test error = 0.5646441411593647
# For user 50, test error = 1.0205783373139818
# For user 51, test error = 1.3216188998676484
# For user 52, test error = 0.7144756166791567
# For user 53, test error = 2.361964132786235
# For user 54, test error = 0.845656143356333
# For user 55, test error = 1.157485324804274
# For user 56, test error = 0.8470073960788981
# For user 57, test error = 0.8767126946541087
# For user 58, test error = 1.1064554903050303
# For user 59, test error = 0.8075122490207277
# For user 60, test error = 0.727519538791292
# For user 61, test error = 0.5160452229999455
# For user 62, test error = 0.7585057524356624
# For user 63, test error = 0.9321227973734365
# For user 64, test error = 0.9035326359032335
# For user 65, test error = 0.6153583724329343
# For user 66, test error = 0.9051206055767591
# For user 67, test error = 0.9207899426314545
# For user 68, test error = 1.0714078865683554
# For user 69, test error = 0.929320593844683
# For user 70, test error = 0.6519076866007679
# For user 71, test error = 1.0715458016109223
# For user 72, test error = 0.47413668268443954
# For user 73, test error = 0.9251812666668888
# For user 74, test error = 0.7526684026161876
# For user 75, test error = 1.6942421518339343
# For user 76, test error = 1.6191391922516944
# For user 77, test error = 1.913919981272795
# For user 78, test error = 1.3154321449861763
# For user 79, test error = 0.9729395257842638
# For user 80, test error = 0.8864663484718153
# For user 81, test error = 1.6026163109073517
# For user 82, test error = 0.9714433778100602
# For user 83, test error = 1.028525389970206
# For user 84, test error = 0.7173959746496603
# For user 85, test error = 1.0391586187717896
# For user 86, test error = 0.6826418274884258
# For user 87, test error = 0.6894314319395025
# For user 88, test error = 0.7626978944495575
# For user 89, test error = 1.6469115323213186
# For user 90, test error = 0.7631293030363386
# For user 91, test error = 0.8465957263577369
# For user 92, test error = 0.7108297207874443
# For user 93, test error = 1.3194375316254097
# For user 94, test error = 1.3131773432088938
# For user 95, test error = 0.5557474235248517
# For user 96, test error = 1.316697844965607
# For user 97, test error = 1.061737128976336
# For user 98, test error = 0.8204497815395528
# For user 99, test error = 1.1989362109799413
# For user 100, test error = 0.9725594250357498
# For user 101, test error = 0.8111681122640306
# For user 102, test error = 0.7082842924353608
# For user 103, test error = 0.7719865352786707
# For user 104, test error = 0.9715366974301575
# For user 105, test error = 0.7056896185973567
# For user 106, test error = 0.5787114812885259
# For user 107, test error = 1.1033670038394747
# For user 108, test error = 1.3660325712123875
# For user 109, test error = 0.7442367055546011
# For user 110, test error = 0.8538893412824448
# For user 111, test error = 0.9940970612886892
# For user 112, test error = 1.3261171949407624
# For user 113, test error = 1.2738586046073916
# For user 114, test error = 0.9302439223399959
# For user 115, test error = 1.1501860504059394
# For user 116, test error = 1.6478209958422674
# For user 117, test error = 0.7385852669079185
# For user 118, test error = 0.8134879300140841
# For user 119, test error = 1.0341571039717732
# For user 120, test error = 0.7416245262793224
# For user 121, test error = 0.9631205914331791
# For user 122, test error = 0.8967790727478481
# For user 123, test error = 0.7397688231642257
# For user 124, test error = 0.5761409839978036
# For user 125, test error = 1.0776369529387202
# For user 126, test error = 1.3685895341293643
# For user 127, test error = 2.217492122737482
# For user 128, test error = 0.5702023535825845
# For user 129, test error = 0.7561555206415568
# For user 130, test error = 1.081741616222928
# For user 131, test error = 0.623132103016711
# For user 132, test error = 0.9363150389747892
# For user 133, test error = 0.806932907432216
# For user 134, test error = 0.9499732860617983
# For user 135, test error = 1.0215425182372613
# For user 136, test error = 1.2123769718561122
# For user 137, test error = 0.7411716086692504
# For user 138, test error = 1.5553413528121312
# For user 139, test error = 1.4677918053691532
# For user 140, test error = 0.9050079015010104
# For user 141, test error = 1.0546250070732202
# For user 142, test error = 0.9480160429324631
# For user 143, test error = 1.8333709964122449
# For user 144, test error = 0.8036030577584306
# For user 145, test error = 1.1151341158550876
# For user 146, test error = 0.686107481668201
# For user 147, test error = 2.1207525566934744
# For user 148, test error = 0.8524557642901096
# For user 149, test error = 1.4854665116916608
# For user 150, test error = 0.8670911120790057
# For user 151, test error = 1.2557175526164974
# For user 152, test error = 0.8322773210819815
# For user 153, test error = 1.799653275457128
# For user 154, test error = 0.774406703040002
# For user 155, test error = 0.6166751468493727
# For user 156, test error = 0.8872163849573682
# For user 157, test error = 1.3108618666306837
# For user 158, test error = 1.1539978954415855
# For user 159, test error = 1.4204093144462706
# For user 160, test error = 1.455704514462328
# For user 161, test error = 1.0374483651293505
# For user 162, test error = 1.106088855094177
# For user 163, test error = 1.1341745639979808
# For user 164, test error = 1.3049635061984193
# For user 165, test error = 0.9314216557866654
# For user 166, test error = 0.764775662639798
# For user 167, test error = 1.0609547218689175
# For user 168, test error = 0.7223685595059494
# For user 169, test error = 1.0157779968702607
# For user 170, test error = 0.8420898845371264
# For user 171, test error = 1.1098551870688862
# For user 172, test error = 1.143621219681817
# For user 173, test error = 0.24837318399560335
# For user 174, test error = 1.1354792186851084
# For user 175, test error = 1.5144360820432499
# For user 176, test error = 0.9494885047845273
# For user 177, test error = 0.8732357436808839
# For user 178, test error = 0.716836904004909
# For user 179, test error = 0.9599718935100328
# For user 180, test error = 0.5580875706989595
# For user 181, test error = 1.035958308359693
# For user 182, test error = 0.9844848778686451
# For user 183, test error = 0.9191820197359077
# For user 184, test error = 0.9321564980608966
# For user 185, test error = 1.3030874927103173
# For user 186, test error = 0.964776078524886
# For user 187, test error = 1.1539577267624326
# For user 188, test error = 1.0116824693564925
# For user 189, test error = 0.7621021775611982
# For user 190, test error = 0.5157770549237046
# For user 191, test error = 1.177121436052559
# For user 192, test error = 1.1383945638409276
# For user 193, test error = 0.9645398121567061
# For user 194, test error = 0.7863180327887288
# For user 195, test error = 1.0741928775882215
# For user 196, test error = 0.8334062019199582
# For user 197, test error = 1.2450523302493435
# For user 198, test error = 1.3723869343803414
# For user 199, test error = 0.9862924269042496
# For user 200, test error = 0.8862517895535289
# For user 201, test error = 1.0327141245261484
# For user 202, test error = 0.7897120343745068
# For user 203, test error = 0.7515626427053372
# For user 204, test error = 0.5271873556598163
# For user 205, test error = 0.6940607766622379
# For user 206, test error = 0.4987324760326904
# For user 207, test error = 1.4998393839506432
# For user 208, test error = 1.0012704087619062
# For user 209, test error = 0.8053498252304697
# For user 210, test error = 0.9771018803022868
# For user 211, test error = 0.8112109634266713
# For user 212, test error = 0.7921587059097953
# For user 213, test error = 0.6694270627010177
# For user 214, test error = 1.1225921553046612
# For user 215, test error = 0.9314223041192644
# For user 216, test error = 1.0535489851649793
# For user 217, test error = 1.1064530907923058
# For user 218, test error = 1.5849978159780345
# For user 219, test error = 0.8776334081813445
# For user 220, test error = 1.079385281723708
# For user 221, test error = 0.8133255453576799
# For user 222, test error = 0.876732847055656
# For user 223, test error = 1.1807023122761444
# For user 224, test error = 1.0456367427552087
# For user 225, test error = 1.0217439978486285
# For user 226, test error = 0.9067047369589443
# For user 227, test error = 0.5763160859882961
# For user 228, test error = 0.9951756534606987
# For user 229, test error = 0.8513646216301448
# For user 230, test error = 1.5243400349099967
# For user 231, test error = 1.1019573128309372
# For user 232, test error = 0.7906509998356226
# For user 233, test error = 1.087646597362912
# For user 234, test error = 1.3306960960119425
# For user 235, test error = 1.0086183121789967
# For user 236, test error = 1.2680909536909435
# For user 237, test error = 0.8144528687803821
# For user 238, test error = 1.2350481082828593
# For user 239, test error = 0.8459073195311526
# For user 240, test error = 1.0941941611162904
# For user 241, test error = 0.7303780383228349
# For user 242, test error = 1.1156853650375336
# For user 243, test error = 1.3035571757555542
# For user 244, test error = 1.2950146015656907
# For user 245, test error = 1.3725364631143107
# For user 246, test error = 1.00191899151537
# For user 247, test error = 0.997424748590334
# For user 248, test error = 0.8558582492866439
# For user 249, test error = 0.6724402551356642
# For user 250, test error = 0.8150552410643107
# For user 251, test error = 0.9070785613288227
# For user 252, test error = 0.9808497495868334
# For user 253, test error = 1.0310461264643977
# For user 254, test error = 0.8842175892493969
# For user 255, test error = 2.500753347934986
# For user 256, test error = 1.0016646070429909
# For user 257, test error = 0.963334009038585
# For user 258, test error = 1.0891787729831903
# For user 259, test error = 1.9715602078681038
# For user 260, test error = 1.2912425789595205
# For user 261, test error = 0.6958201983295855
# For user 262, test error = 1.040304442796779
# For user 263, test error = 0.690249079217133
# For user 264, test error = 1.3980953912414085
# For user 265, test error = 0.8097902162754126
# For user 266, test error = 1.1828397803114368
# For user 267, test error = 1.1206749107276603
# For user 268, test error = 1.1573824631052825
# For user 269, test error = 1.1706105206469033
# For user 270, test error = 1.4452649688532337
# For user 271, test error = 0.957479619469184
# For user 272, test error = 1.3762786225770653
# For user 273, test error = 1.292958850536922
# For user 274, test error = 0.8942027377028348
# For user 275, test error = 1.159925559851379
# For user 276, test error = 0.6305132972089773
# For user 277, test error = 0.5126679848571065
# For user 278, test error = 0.9225308333853592
# For user 279, test error = 0.8966771126022292
# For user 280, test error = 0.9429607678248197
# For user 281, test error = 0.560527549177033
# For user 282, test error = 0.6554238437612042
# For user 283, test error = 0.6235445159330889
# For user 284, test error = 0.9896027328466265
# For user 285, test error = 0.6473778792808477
# For user 286, test error = 0.6174810559726384
# For user 287, test error = 1.5698566607844566
# For user 288, test error = 0.8178474397047258
# For user 289, test error = 0.6391531939155578
# For user 290, test error = 0.7835609942569486
# For user 291, test error = 1.3620327090178894
# For user 292, test error = 0.9912258185125464
# For user 293, test error = 1.1482309912154804
# For user 294, test error = 1.1647735235465555
# For user 295, test error = 1.3103672257814412
# For user 296, test error = 0.4587844362390751
# For user 297, test error = 1.3197801504057083
# For user 298, test error = 1.4282633661269926
# For user 299, test error = 0.8623813180597742
# For user 300, test error = 1.1296543138134423
# For user 301, test error = 1.1191331394782578
# For user 302, test error = 0.6988290931840865
# For user 303, test error = 0.8487014488983374
# For user 304, test error = 1.024132817472668
# For user 305, test error = 1.0104662740051953
# For user 306, test error = 0.848401229935015
# For user 307, test error = 1.0387448078373904
# For user 308, test error = 1.6430802581749757
# For user 309, test error = 0.6158720275354407
# For user 310, test error = 1.5880073666951746
# For user 311, test error = 1.7372256477414019
# For user 312, test error = 0.7665873000149191
# For user 313, test error = 1.2198328672009122
# For user 314, test error = 0.866805467221547
# For user 315, test error = 1.0502558256608527
# For user 316, test error = 0.9500180692723841
# For user 317, test error = 1.106785595374868
# For user 318, test error = 0.834584581612661
# For user 319, test error = 1.1171467132320945
# For user 320, test error = 0.6733710705064921
# For user 321, test error = 0.8834918478974443
# For user 322, test error = 1.4772396864730408
# For user 323, test error = 0.9732130102360168
# For user 324, test error = 0.9867352459116603
# For user 325, test error = 0.7419359257797047
# For user 326, test error = 0.9493176757286136
# For user 327, test error = 0.8342901598511565
# For user 328, test error = 1.5085320544295062
# For user 329, test error = 2.244982708953099
# For user 330, test error = 0.9837882363996983
# For user 331, test error = 0.8851123990291279
# For user 332, test error = 0.9551890181368334
# For user 333, test error = 1.0218392536044965
# For user 334, test error = 0.7071945862623822
# For user 335, test error = 0.8650565217474016
# For user 336, test error = 1.1199994827945723
# For user 337, test error = 1.0115650081498513
# For user 338, test error = 1.4415959295032437
# For user 339, test error = 0.837992696492016
# For user 340, test error = 0.8500900655452839
# For user 341, test error = 0.6687046827550911
# For user 342, test error = 1.1122581365402013
# For user 343, test error = 1.0909674268832392
# For user 344, test error = 0.9475874821391154
# For user 345, test error = 1.019876764630534
# For user 346, test error = 0.5334279087969026
# For user 347, test error = 0.8448365992666511
# For user 348, test error = 0.9259659883926423
# For user 349, test error = 0.6523981760883802
# For user 350, test error = 1.0489550794526326
# For user 351, test error = 0.6405865019687477
# For user 352, test error = 0.7957890216360463
# For user 353, test error = 0.8264003593369162
# For user 354, test error = 0.6600207863018476
# For user 355, test error = 0.7495207358999572
# For user 356, test error = 0.7998146337515198
# For user 357, test error = 0.8121586991434209
# For user 358, test error = 1.0527650540533233
# For user 359, test error = 0.8516383317186854
# For user 360, test error = 1.5616363680735061
# For user 361, test error = 1.2250673530854939
# For user 362, test error = 0.6478529381751995
# For user 363, test error = 1.3952995677540638
# For user 364, test error = 0.9491091986991104
# For user 365, test error = 1.4004654868051682
# For user 366, test error = 1.0824168609927076
# For user 367, test error = 1.197140456935721
# For user 368, test error = 0.8098846545450241
# For user 369, test error = 0.92011953769938
# For user 370, test error = 1.073505955071196
# For user 371, test error = 0.8206828565610341
# For user 372, test error = 1.0118802858821587
# For user 373, test error = 1.1724041346423717
# For user 374, test error = 0.8046498920491664
# For user 375, test error = 1.1823859670232655
# For user 376, test error = 0.9807937575464037
# For user 377, test error = 1.0623407042182793
# For user 378, test error = 0.7072877284521157
# For user 379, test error = 1.0014467907345497
# For user 380, test error = 0.9229991682291141
# For user 381, test error = 0.8209364450140385
# For user 382, test error = 0.9332924718242716
# For user 383, test error = 0.8970266350649838
# For user 384, test error = 0.8487407273817871
# For user 385, test error = 0.8500754725277565
# For user 386, test error = 0.8499558682919635
# For user 387, test error = 0.8639368062724058
# For user 388, test error = 0.6667616398143845
# For user 389, test error = 0.8931359308772759
# For user 390, test error = 0.8990797560410094
# For user 391, test error = 0.9706786548889548
# For user 392, test error = 1.3149044493845057
# For user 393, test error = 1.3229498573412715
# For user 394, test error = 1.0029008187524306
# For user 395, test error = 1.178164104654485
# For user 396, test error = 0.6121508043870226
# For user 397, test error = 0.7820858467098581
# For user 398, test error = 0.45053463806758753
# For user 399, test error = 2.057450023304531
# For user 400, test error = 0.6481509099064963
# For user 401, test error = 0.7393602199039246
# For user 402, test error = 0.8517350418426557
# For user 403, test error = 0.7478083288465632
# For user 404, test error = 0.7136414713694974
# For user 405, test error = 0.5550444605941687
# For user 406, test error = 2.0978029107904885
# For user 407, test error = 1.1935245316679193
# For user 408, test error = 1.12098172646398
# For user 409, test error = 1.1073799516030727
# For user 410, test error = 0.9541661120242094
# For user 411, test error = 0.842176062616124
# For user 412, test error = 1.2312963946481028
# For user 413, test error = 1.59806271044546
# For user 414, test error = 0.9083257432514898
# For user 415, test error = 0.633647134541079
# For user 416, test error = 1.058265383092083
# For user 417, test error = 0.9104193197237825
# For user 418, test error = 1.3729839144372957
# For user 419, test error = 0.9089977355817
# For user 420, test error = 0.7113020453077986
# For user 421, test error = 0.7480098968251728
# For user 422, test error = 1.0629435334662136
# For user 423, test error = 1.0230106135711015
# For user 424, test error = 0.6955415770922674
# For user 425, test error = 0.743953068806463
# For user 426, test error = 1.1984365551789573
# For user 427, test error = 1.0965870121066938
# For user 428, test error = 1.0989784912106813
# For user 429, test error = 0.6301176070184674
# For user 430, test error = 0.9347450915069304
# For user 431, test error = 1.3983299540598773
# For user 432, test error = 0.8984633152529917
# For user 433, test error = 1.0955078679785393
# For user 434, test error = 0.9672179502390117
# For user 435, test error = 0.793141607951877
# For user 436, test error = 0.7084355561682669
# For user 437, test error = 0.9284586457669229
# For user 438, test error = 0.823504599902729
# For user 439, test error = 1.3349809857329475
# For user 440, test error = 0.7605509196997783
# For user 441, test error = 0.9439179487744082
# For user 442, test error = 2.2496514063809525
# For user 443, test error = 0.5692199821584921
# For user 444, test error = 0.6924567137716231
# For user 445, test error = 0.8284838487374262
# For user 446, test error = 0.6707617834181042
# For user 447, test error = 0.8857712156576104
# For user 448, test error = 1.0226307969759898
# For user 449, test error = 0.8453016459404264
# ...
# For user 263, test error = 0.6691471823690537
# For user 264, test error = 1.195589831094677
# For user 265, test error = 0.7790049194646844
# For user 266, test error = 1.1115915611314384
# For user 267, test error = 1.138879087553305
# For user 268, test error = 1.1808838343454504
# For user 269, test error = 1.045135779641937
# For user 270, test error = 1.364583210613649
# For user 271, test error = 0.8695072560164768
# For user 272, test error = 1.172952904387355
# For user 273, test error = 0.9778505877275581
# For user 274, test error = 0.7686720226603915
# For user 275, test error = 1.1353777740123945
# For user 276, test error = 0.7663862964652339
# For user 277, test error = 0.578810854509057
# For user 278, test error = 0.8300103416298047
# For user 279, test error = 0.8226604325228876
# For user 280, test error = 0.9561244749021747
# For user 281, test error = 0.38473640389452435
# For user 282, test error = 0.6537714617658077
# For user 283, test error = 0.6758257304238404
# For user 284, test error = 0.9938081970209859
# For user 285, test error = 0.641878001359267
# For user 286, test error = 0.6367891421393839
# For user 287, test error = 1.3972048030449078
# For user 288, test error = 0.7686522865925643
# For user 289, test error = 0.3535807032018494
# For user 290, test error = 0.718697159254598
# For user 291, test error = 1.3140774768524597
# For user 292, test error = 0.9565131833964046
# For user 293, test error = 0.9285198466794952
# For user 294, test error = 1.1687983641643915
# For user 295, test error = 1.1305823277640978
# For user 296, test error = 0.5383770746633253
# For user 297, test error = 1.186723812300419
# For user 298, test error = 1.3848915388766248
# For user 299, test error = 0.6956656491450782
# For user 300, test error = 0.7858627310944121
# For user 301, test error = 0.9559072763907328
# For user 302, test error = 0.5310369632178354
# For user 303, test error = 0.7790040361272809
# For user 304, test error = 0.9963743795376244
# For user 305, test error = 0.9792385603772908
# For user 306, test error = 0.8452586603199994
# For user 307, test error = 1.0197950387660506
# For user 308, test error = 1.7096168089603472
# For user 309, test error = 0.6468545926747951
# For user 310, test error = 1.2594836091554982
# For user 311, test error = 1.4961165996108414
# For user 312, test error = 0.6441483606761942
# For user 313, test error = 1.120307645194407
# For user 314, test error = 0.9160123493257242
# For user 315, test error = 1.0776294743197536
# For user 316, test error = 0.9831253229603978
# For user 317, test error = 0.9296959615510264
# For user 318, test error = 0.7627649904553961
# For user 319, test error = 1.1035926646864442
# For user 320, test error = 0.5706736438648069
# For user 321, test error = 0.7775061235104959
# For user 322, test error = 1.4384596719527492
# For user 323, test error = 0.8497918066104753
# For user 324, test error = 1.023120741887586
# For user 325, test error = 0.7262557232396647
# For user 326, test error = 0.9370750506699864
# For user 327, test error = 0.9821168482165091
# For user 328, test error = 1.431932573761325
# For user 329, test error = 2.5544797068765623
# For user 330, test error = 0.8630158673663697
# For user 331, test error = 0.7718854980011388
# For user 332, test error = 0.8138996255564306
# For user 333, test error = 1.0075137436737376
# For user 334, test error = 0.6436591322759848
# For user 335, test error = 0.7340117618882265
# For user 336, test error = 0.8246105306459788
# For user 337, test error = 1.1663506077923076
# For user 338, test error = 1.3864111330842437
# For user 339, test error = 0.8233038183002032
# For user 340, test error = 0.7347670319274137
# For user 341, test error = 0.6510365589957681
# For user 342, test error = 1.0435773432670878
# For user 343, test error = 0.9761412291873441
# For user 344, test error = 1.0717626426028928
# For user 345, test error = 0.8964427850371136
# For user 346, test error = 0.5015751270663811
# For user 347, test error = 0.8526601958435791
# For user 348, test error = 0.8880794922583493
# For user 349, test error = 0.8157531562847848
# For user 350, test error = 0.8950359480810088
# For user 351, test error = 0.6277023067403518
# For user 352, test error = 0.7433473772197593
# For user 353, test error = 0.8414779426120895
# For user 354, test error = 0.5440995146433147
# For user 355, test error = 0.5880158010664667
# For user 356, test error = 0.697926760640825
# For user 357, test error = 0.7565772455470194
# For user 358, test error = 1.0484063643424373
# For user 359, test error = 0.8222723747308057
# For user 360, test error = 1.5336763982951347
# For user 361, test error = 1.0948839091914628
# For user 362, test error = 0.7207727083995811
# For user 363, test error = 1.5563537234772495
# For user 364, test error = 0.9195538766317334
# For user 365, test error = 1.3513297093388212
# For user 366, test error = 0.9368799043078474
# For user 367, test error = 1.1301522967593063
# For user 368, test error = 0.7429613093154347
# For user 369, test error = 0.7891831977142774
# For user 370, test error = 0.9271377051599717
# For user 371, test error = 0.8356556816767484
# For user 372, test error = 0.9903331356722594
# For user 373, test error = 1.1372591580393745
# For user 374, test error = 0.8390424292470056
# For user 375, test error = 1.0048526994678895
# For user 376, test error = 0.9021125164827392
# For user 377, test error = 1.0098729120493597
# For user 378, test error = 0.4584984533097814
# For user 379, test error = 0.9495800513213608
# For user 380, test error = 0.9117197505148263
# For user 381, test error = 0.8159084012794676
# For user 382, test error = 0.8645035425865006
# For user 383, test error = 0.8654499002948693
# For user 384, test error = 0.8069989944920994
# For user 385, test error = 0.7978947494535827
# For user 386, test error = 0.8293787697331849
# For user 387, test error = 0.8091585497827681
# For user 388, test error = 0.7308468878298727
# For user 389, test error = 0.7454118557544781
# For user 390, test error = 0.8433691470280554
# For user 391, test error = 0.8914269469466292
# For user 392, test error = 1.1397946532955041
# For user 393, test error = 1.308884080445274
# For user 394, test error = 1.0614711177206297
# For user 395, test error = 1.0636218732008602
# For user 396, test error = 0.6120871194986957
# For user 397, test error = 0.5331121974551983
# For user 398, test error = 0.4364912342632101
# For user 399, test error = 1.8478700650022424
# For user 400, test error = 0.6253315281120698
# For user 401, test error = 0.8181338517126253
# For user 402, test error = 0.9054517795768858
# For user 403, test error = 0.58646665714226
# For user 404, test error = 0.525169421419809
# For user 405, test error = 0.5026089773020245
# For user 406, test error = 2.167291904775384
# For user 407, test error = 0.94224262933196
# For user 408, test error = 1.0602370137379091
# For user 409, test error = 1.0338715316688556
# For user 410, test error = 0.8423775671315095
# For user 411, test error = 0.7093727707559135
# For user 412, test error = 1.140801987640733
# For user 413, test error = 1.3547510347104041
# For user 414, test error = 0.8228846575187697
# For user 415, test error = 0.47074569892824875
# For user 416, test error = 1.043238531935751
# For user 417, test error = 0.7964287997543883
# For user 418, test error = 1.4862250235748231
# For user 419, test error = 0.9388342414584477
# For user 420, test error = 0.6219203065052987
# For user 421, test error = 0.614894712334738
# For user 422, test error = 0.9803740494702297
# For user 423, test error = 0.9454185938093395
# For user 424, test error = 0.7377209334983519
# For user 425, test error = 0.5702513377134804
# For user 426, test error = 1.2905808091438293
# For user 427, test error = 0.956513997730196
# For user 428, test error = 1.0843303795809147
# For user 429, test error = 0.7016043238274274
# For user 430, test error = 0.7774570631093743
# For user 431, test error = 1.231003746682901
# For user 432, test error = 0.884843741667424
# For user 433, test error = 1.147859115647507
# For user 434, test error = 0.7841307526704381
# For user 435, test error = 0.6634218368034338
# For user 436, test error = 0.5637514101137185
# For user 437, test error = 0.8987876847481364
# For user 438, test error = 0.7460000448715367
# For user 439, test error = 0.8717277664631986
# For user 440, test error = 0.5192579478105592
# For user 441, test error = 0.7991716296095774
# For user 442, test error = 2.1695975279595583
# For user 443, test error = 0.620808305833103
# For user 444, test error = 0.5877057068079853
# For user 445, test error = 0.8003589412937384
# For user 446, test error = 0.7319132718695907
# For user 447, test error = 0.8134971519880354
# For user 448, test error = 0.9615892454515563
# For user 449, test error = 0.6169057145231548
# For user 450, test error = 0.6373139762913672
# For user 451, test error = 0.9012038871301327
# For user 452, test error = 1.3769551330327325
# For user 453, test error = 1.224913103755444
# For user 454, test error = 0.7595186657315159
# For user 455, test error = 0.539783852216803
# For user 456, test error = 0.7389097433681663
# For user 457, test error = 1.0730748999145148
# For user 458, test error = 0.9380050386330032
# For user 459, test error = 0.7458275140093372
# For user 460, test error = 0.6975419490822745
# For user 461, test error = 2.067706072730428
# For user 462, test error = 1.0526267533417355
# For user 463, test error = 0.611088059957688
# For user 464, test error = 0.8765674763703233
# For user 465, test error = 0.6590641451103302
# For user 466, test error = 0.7367888308349952
# For user 467, test error = 0.9987774549266527
# For user 468, test error = 0.9636142499099416
# For user 469, test error = 0.7938558807984907
# For user 470, test error = 0.6249037470580826
# For user 471, test error = 0.43987298162205096
# For user 472, test error = 0.9487579542040904
# For user 473, test error = 0.7127454871425362
# For user 474, test error = 0.8213760819783361
# For user 475, test error = 0.9920839971415977
# For user 476, test error = 0.5951767669683796
# For user 477, test error = 0.8911682169017539
# For user 478, test error = 0.8372000087153902
# For user 479, test error = 0.9543637913409401
# For user 480, test error = 0.8568314682339946
# For user 481, test error = 0.9868170265399685
# For user 482, test error = 1.0326145565269076
# For user 483, test error = 0.833862831341967
# For user 484, test error = 1.101510709453053
# For user 485, test error = 0.6860967620058268
# For user 486, test error = 1.0219493456623587
# For user 487, test error = 0.7595284178902817
# For user 488, test error = 0.9822563669438252
# For user 489, test error = 1.0895331233716026
# For user 490, test error = 0.883603775489532
# For user 491, test error = 0.9960917552261135
# For user 492, test error = 1.3445901561078852
# For user 493, test error = 0.6422932423602995
# For user 494, test error = 1.1300680427955088
# For user 495, test error = 1.1216562569858652
# For user 496, test error = 0.5840373349666403
# For user 497, test error = 1.369554931845545
# For user 498, test error = 1.2992126704679745
# For user 499, test error = 0.8947088796836673
# For user 500, test error = 1.522842747511726
# For user 501, test error = 1.0691654917195939
# For user 502, test error = 1.9585294622436724
# For user 503, test error = 1.2679969991474498
# For user 504, test error = 0.7658905424059335
# For user 505, test error = 0.8400193216141884
# For user 506, test error = 1.3926110656491897
# For user 507, test error = 1.0193084368336083
# For user 508, test error = 1.7521636018354656
# For user 509, test error = 0.8178366168226399
# For user 510, test error = 1.2007760208125073
# For user 511, test error = 0.40685685674273353
# For user 512, test error = 0.9421833600854269
# For user 513, test error = 1.0331675215138496
# For user 514, test error = 0.8273916622784852
# For user 515, test error = 0.6527605650073487
# For user 516, test error = 0.82903139556057
# For user 517, test error = 1.8071834859849945
# For user 518, test error = 0.7814242983833151
# For user 519, test error = 0.6174531586658712
# For user 520, test error = 0.8757733512932643
# For user 521, test error = 0.3737981268245575
# For user 522, test error = 1.0828819745444633
# For user 523, test error = 0.8857562367147687
# For user 524, test error = 0.708348803797958
# For user 525, test error = 0.6642053375861606
# For user 526, test error = 0.6216861436569298
# For user 527, test error = 1.1204213456382113
# For user 528, test error = 0.876485086422938
# For user 529, test error = 0.4904173421767138
# For user 530, test error = 0.5336667527030449
# For user 531, test error = 1.3930489360862175
# For user 532, test error = 0.8307248557511183
# For user 533, test error = 0.9793089151186394
# For user 534, test error = 0.9140548624050975
# For user 535, test error = 1.4174866272352191
# For user 536, test error = 1.1922089263921278
# For user 537, test error = 1.0735469897790315
# For user 538, test error = 0.8675723300910518
# For user 539, test error = 1.3087914334044852
# For user 540, test error = 1.0412785598267689
# For user 541, test error = 1.0669546078768704
# For user 542, test error = 1.3372436719343381
# For user 543, test error = 1.7094170807972513
# For user 544, test error = 1.4340368316642087
# For user 545, test error = 0.9834006193410375
# For user 546, test error = 1.395946041108369
# For user 547, test error = 0.8661097862779645
# For user 548, test error = 1.1929625083347875
# For user 549, test error = 1.2557872151849772
# For user 550, test error = 0.2962817794029455
# For user 551, test error = 0.7585819145659307
# For user 552, test error = 0.8785889911779351
# For user 553, test error = 0.8524030711172916
# For user 554, test error = 1.3217449318123369
# For user 555, test error = 1.0110177407097989
# For user 556, test error = 1.1700965422875669
# For user 557, test error = 0.8398859007025385
# For user 558, test error = 0.8777696560176086
# For user 559, test error = 0.7575155421823702
# For user 560, test error = 0.5367345704689039
# For user 561, test error = 0.6545200304736299
# For user 562, test error = 0.8827109981934291
# For user 563, test error = 0.8498912173152158
# For user 564, test error = 1.2189001265055215
# For user 565, test error = 0.48886677262475897
# For user 566, test error = 0.815573930303939
# For user 567, test error = 1.4795079306180576
# For user 568, test error = 1.2682276665545196
# For user 569, test error = 0.7666960553801502
# For user 570, test error = 0.49976772267689235
# For user 571, test error = 1.356301831082431
# For user 572, test error = 0.7906332187483806
# For user 573, test error = 0.964575110563072
# For user 574, test error = 0.3903893032342689
# For user 575, test error = 1.2768302210666471
# For user 576, test error = 1.0597089437484952
# For user 577, test error = 0.7622418011254759
# For user 578, test error = 1.1881566151502791
# For user 579, test error = 0.9714128164991288
# For user 580, test error = 1.0357429093524892
# For user 581, test error = 0.5850438932149782
# For user 582, test error = 0.7024514018452589
# For user 583, test error = 0.9227147991936641
# For user 584, test error = 1.115240694939471
# For user 585, test error = 0.8269133175301288
# For user 586, test error = 1.0126865329017891
# For user 587, test error = 1.1512997526125284
# For user 588, test error = 0.6519181844551324
# For user 589, test error = 0.9525475674984037
# For user 590, test error = 0.5730030273328969
# For user 591, test error = 1.1218514088375797
# For user 592, test error = 1.0978279336568724
# For user 593, test error = 1.3607462337147913
# For user 594, test error = 1.7628583217179814
# For user 595, test error = 1.0195678610505126
# For user 596, test error = 0.6576922999513833
# For user 597, test error = 0.9866774632367724
# For user 598, test error = 1.9943394308338847
# For user 599, test error = 1.0279483729480572
# For user 600, test error = 1.0180136571224774
# For user 601, test error = 0.6594551598305652
# For user 602, test error = 0.8971888269730607
# For user 603, test error = 1.0896530077131383
# For user 604, test error = 0.9381518647368463
# For user 605, test error = 1.1260793776171811
# For user 606, test error = 0.7193361124164991
# For user 607, test error = 1.127080803941219
# For user 608, test error = 0.9305973023031952
# For user 609, test error = 0.565567166909502
# For user 610, test error = 0.7904481635238246
# K:15, rmse is 0.9468164153673506.

# %%
def Recall(train, test, N, K, W):
    hit = 0
    realall = 0
    for user in train.keys():
        tu = set(test[user]['movieId'].tolist())
        recommend_list = Recommend(user, train, N, K, W)
        user_hit = 0
        for item in recommend_list:
            if item in tu:
                user_hit += 1
                hit += 1
        #print('For user:', user, ', recall is ', user_hit/len(tu))
        realall += len(tu)
    return hit/(realall*1.0)

def Precision(train, test, N, K, W):
    hit = 0
    realall = 0
    for user in train.keys():
        tu = set(test[user]['movieId'].tolist())
        recommend_list = Recommend(user, train, N, K, W)
        user_hit = 0
        for item in recommend_list:
            if item in tu:
                hit += 1
                user_hit += 1
        #print('For user:', user, ', precision is ', user_hit/N)
        realall += N
    return hit/(realall*1.0)
